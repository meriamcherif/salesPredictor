# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
types = {'StateHoliday': np.dtype(str)}
train = pd.read_csv("/content/gdrive/MyDrive/futureSales/assets/train.csv", parse_dates=[2], nrows=66901, dtype=types)
store = pd.read_csv("/content/gdrive/MyDrive/futureSales/assets/store.csv")

# %%
not_open = train[(train['Open'] == 0) & (train['Sales'] != 0)]
print("No closed store with sales: " + str(not_open.size == 0))
# Out:
# No closed store with sales: True

# %%
no_sales = train[(train['Open'] == 1) & (train['Sales'] <= 0)]
print("No open store with no sales: " + str(no_sales.size == 0))
# Out:
# No open store with no sales: True

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(7, sharex=True, sharey=True)
for i in range(1, 8):
    mask = train[train['DayOfWeek'] == i]
    ax[i - 1].set_title("Day {0}".format(i))
    ax[i - 1].scatter(mask['Customers'], mask['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
plt.scatter(train['Customers'], train['Sales'], c=train['DayOfWeek'], alpha=0.7, cmap=plt.cm.get_cmap('viridis'))

plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()
# Out:
# <ipython-input-7-3616624ade31>:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(train['Customers'], train['Sales'], c=train['DayOfWeek'], alpha=0.7, cmap=plt.cm.get_cmap('viridis'))

# %%
for i in ["0", "1" ,"a", "b", "c"]:
    data = train[train['StateHoliday'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['Customers'], data['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
for i in [0, 1]:
    data = train[train['SchoolHoliday'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['Customers'], data['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
for i in [0, 1]:
    data = train[train['Promo'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['Customers'], data['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
train['SalesPerCustomer'] = train['Sales'] / train['Customers']

avg_store = train.groupby('Store')[['Sales', 'Customers', 'SalesPerCustomer']].mean()
avg_store.rename(columns=lambda x: 'Avg' + x, inplace=True)
store = pd.merge(avg_store.reset_index(), store, on='Store')
store.head()
# Out:
#    Store     AvgSales  AvgCustomers  AvgSalesPerCustomer StoreType Assortment  \
# 0      1  3791.426230    434.934426             8.670743         c          a
# 1      2  4332.266667    517.016667             8.459276         a          a
# 2      3  6030.983333    609.316667             9.785061         a          a
# 3      4  8530.850000   1101.933333             7.702043         c          c
# 4      5  3997.250000    453.250000             8.764831         a          a
#
#    CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0               1270.0                        9.0                    2008.0
# 1                570.0                       11.0                    2007.0
# 2              14130.0                       12.0                    2006.0
# 3                620.0                        9.0                    2009.0
# 4              29910.0                        4.0                    2015.0
#
#    Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0       0              NaN              NaN              NaN
# 1       1             13.0           2010.0  Jan,Apr,Jul,Oct
# 2       1             14.0           2011.0  Jan,Apr,Jul,Oct
# 3       0              NaN              NaN              NaN
# 4       0              NaN              NaN              NaN

# %%
for i in ['a', 'b', 'c', 'd']:
    data = store[store['StoreType'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['AvgCustomers'], data['AvgSales'], label=i)

plt.legend()
plt.xlabel('Average Customers')
plt.ylabel('Average Sales')
plt.show()

# %%
for i in [0, 1]:
    data = store[store['Promo2'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['AvgCustomers'], data['AvgSales'], label=i)

plt.legend()
plt.xlabel('Average Customers')
plt.ylabel('Average Sales')
plt.show()

# %%
# fill NaN values
store["CompetitionDistance"].fillna(-1)
plt.scatter(store['CompetitionDistance'], store['AvgSales'])

plt.xlabel('CompetitionDistance')
plt.ylabel('Average Sales')
plt.show()

# %%
def build_features(train, store):
    # Convert string types into integers
    store['StoreType'] = store['StoreType'].astype('category').cat.codes
    store['Assortment'] = store['Assortment'].astype('category').cat.codes
    train["StateHoliday"] = train["StateHoliday"].astype('category').cat.codes

    merged = pd.merge(train, store, on='Store', how='left')

    # remove NaNs
    NaN_replace = 0
    merged.fillna(NaN_replace, inplace=True)

    merged['Year'] = merged.Date.dt.year
    merged['Month'] = merged.Date.dt.month
    merged['Day'] = merged.Date.dt.day
    merged['Week'] = merged.Date.dt.week

    # Number of months that competition has existed for
    merged['MonthsCompetitionOpen'] = \
        12 * (merged['Year'] - merged['CompetitionOpenSinceYear']) + \
        (merged['Month'] - merged['CompetitionOpenSinceMonth'])
    merged.loc[merged['CompetitionOpenSinceYear'] ==
               NaN_replace, 'MonthsCompetitionOpen'] = NaN_replace

    # Number of weeks that promotion has existed for
    merged['WeeksPromoOpen'] = \
        12 * (merged['Year'] - merged['Promo2SinceYear']) + \
        (merged['Date'].dt.weekofyear - merged['Promo2SinceWeek'])
    merged.loc[merged['Promo2SinceYear'] ==
               NaN_replace, 'WeeksPromoOpen'] = NaN_replace

    toInt = [
        'CompetitionOpenSinceMonth',
        'CompetitionOpenSinceYear',
        'Promo2SinceWeek',
        'Promo2SinceYear',
        'MonthsCompetitionOpen',
        'WeeksPromoOpen'
    ]
    merged[toInt] = merged[toInt].astype(int)

    return merged

med_store = train.groupby('Store')[['Sales', 'Customers', 'SalesPerCustomer']].median()
med_store.rename(columns=lambda x: 'Med' + x, inplace=True)

store = pd.merge(med_store.reset_index(), store, on='Store')
features = build_features(train, store)
features.head()
# Out:
# <ipython-input-15-5dc1ec829914>:16: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   merged['Week'] = merged.Date.dt.week
# <ipython-input-15-5dc1ec829914>:28: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   (merged['Date'].dt.weekofyear - merged['Promo2SinceWeek'])
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1             0
# 1      2          5 2015-07-31   6064        625     1      1             0
# 2      3          5 2015-07-31   8314        821     1      1             0
# 3      4          5 2015-07-31  13995       1498     1      1             0
# 4      5          5 2015-07-31   4822        559     1      1             0
#
#    SchoolHoliday  SalesPerCustomer  ...  Promo2  Promo2SinceWeek  \
# 0              1          9.482883  ...       0                0
# 1              1          9.702400  ...       1               13
# 2              1         10.126675  ...       1               14
# 3              1          9.342457  ...       0                0
# 4              1          8.626118  ...       0                0
#
#    Promo2SinceYear    PromoInterval  Year  Month  Day  Week  \
# 0                0                0  2015      7   31    31
# 1             2010  Jan,Apr,Jul,Oct  2015      7   31    31
# 2             2011  Jan,Apr,Jul,Oct  2015      7   31    31
# 3                0                0  2015      7   31    31
# 4                0                0  2015      7   31    31
#
#    MonthsCompetitionOpen  WeeksPromoOpen
# 0                     82               0
# 1                     92              78
# 2                    103              65
# 3                     70               0
# 4                      3               0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
X = [
    'Store',
    'Customers',
    'CompetitionDistance',

    'Promo',
    'Promo2',

#     'SchoolHoliday',
    'StateHoliday',
    'StoreType',
    'Assortment',

    'AvgSales',
    'AvgCustomers',
    'AvgSalesPerCustomer',

    'MedSales',
    'MedCustomers',
    'MedSalesPerCustomer',

    'DayOfWeek',
    'Week',
    'Day',
    'Month',
    'Year',

    'CompetitionOpenSinceMonth',
    'CompetitionOpenSinceYear',
    'Promo2SinceWeek',
    'Promo2SinceYear',

#     'MonthsCompetitionOpen',
#     'WeeksPromoOpen'
]
X_train, X_test, y_train, y_test = train_test_split(
    features[X], features['Sales'], test_size=0.15, random_state=10)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer

# Error calculating function according to kaggle
def rmspe(y, y_hat):
    return np.sqrt(np.mean(((y - y_hat) / y) ** 2))

rmpse_scorer = make_scorer(rmspe, greater_is_better = False) # Loss function

def score(model, X_train, y_train, y_test, y_hat):
    score = cross_val_score(model, X_train, y_train, scoring=rmpse_scorer, cv=5)
    print('Mean', score.mean())
    print('Variance', score.var())
    print('RMSPE', rmspe(y_test, y_hat))

def plot_importance(model):
    k = list(zip(X, model.feature_importances_))
    k.sort(key=lambda tup: tup[1])

    labels, vals = zip(*k)

    plt.barh(np.arange(len(X)), vals, align='center')
    plt.yticks(np.arange(len(X)), labels)

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree = DecisionTreeRegressor()
decision_tree.fit(X_train, y_train)
plot_importance(decision_tree)

# %%
y_hat = decision_tree.predict(X_test)
score(decision_tree, X_train, y_train, y_test, y_hat)
# Out:
# Mean -0.08478791472952311
# Variance 2.1261127844813515e-06
# RMSPE 0.08050917651543694

# %%
from sklearn.ensemble import RandomForestRegressor
randomForest = RandomForestRegressor(n_estimators=25, n_jobs=-1, verbose=1)
randomForest.fit(X_train, y_train)
plot_importance(randomForest)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   10.0s finished

# %%
y_hat = randomForest.predict(X_test)
score(randomForest, X_train, y_train, y_test, y_hat)
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  25 out of  25 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    8.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  25 out of  25 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    8.4s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  25 out of  25 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    7.7s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  25 out of  25 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    7.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  25 out of  25 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Mean -0.061687820417640774
# Variance 8.156408640889288e-07
# RMSPE 0.058616823651132285
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    8.7s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  25 out of  25 | elapsed:    0.1s finished

# %%
import xgboost as xgb

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y,yhat)

xgboost_tree = xgb.XGBRegressor(
    n_jobs = -1,
    n_estimators = 1000,
    eta = 0.1,
    max_depth = 2,
    min_child_weight = 2,
    subsample = 0.8,
    colsample_bytree = 0.8,
    tree_method = 'exact',
    reg_alpha = 0.05,
    silent = 0,
    random_state = 1023
)
xgboost_tree.fit(X_train[X], np.log1p(y_train),
                 eval_set = [(X_train[X], np.log1p(y_train)), (X_test[X], np.log1p(y_test))],
                 eval_metric = rmspe_xg,
                 early_stopping_rounds = 300
                )
# Out:
# [13:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [0]	validation_0-rmse:6.91883	validation_0-rmspe:inf	validation_1-rmse:6.94447	validation_1-rmspe:inf
# [1]	validation_0-rmse:6.22819	validation_0-rmspe:inf	validation_1-rmse:6.25123	validation_1-rmspe:inf
# [2]	validation_0-rmse:5.60675	validation_0-rmspe:inf	validation_1-rmse:5.62735	validation_1-rmspe:inf
# [3]	validation_0-rmse:5.04755	validation_0-rmspe:inf	validation_1-rmse:5.06597	validation_1-rmspe:inf
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [186]	validation_0-rmse:0.09172	validation_0-rmspe:inf	validation_1-rmse:0.08878	validation_1-rmspe:inf
# [187]	validation_0-rmse:0.09164	validation_0-rmspe:inf	validation_1-rmse:0.08870	validation_1-rmspe:inf
# [188]	validation_0-rmse:0.09139	validation_0-rmspe:inf	validation_1-rmse:0.08862	validation_1-rmspe:inf
# [189]	validation_0-rmse:0.09127	validation_0-rmspe:inf	validation_1-rmse:0.08845	validation_1-rmspe:inf
# [190]	validation_0-rmse:0.09114	validation_0-rmspe:inf	validation_1-rmse:0.08831	validation_1-rmspe:inf
# [191]	validation_0-rmse:0.09107	validation_0-rmspe:inf	validation_1-rmse:0.08823	validation_1-rmspe:inf
# [192]	validation_0-rmse:0.09100	validation_0-rmspe:inf	validation_1-rmse:0.08820	validation_1-rmspe:inf
# [193]	validation_0-rmse:0.09077	validation_0-rmspe:inf	validation_1-rmse:0.08796	validation_1-rmspe:inf
# [194]	validation_0-rmse:0.09061	validation_0-rmspe:inf	validation_1-rmse:0.08776	validation_1-rmspe:inf
# [195]	validation_0-rmse:0.09050	validation_0-rmspe:inf	validation_1-rmse:0.08768	validation_1-rmspe:inf
# [196]	validation_0-rmse:0.09032	validation_0-rmspe:inf	validation_1-rmse:0.08754	validation_1-rmspe:inf
# [197]	validation_0-rmse:0.09015	validation_0-rmspe:inf	validation_1-rmse:0.08748	validation_1-rmspe:inf
# [198]	validation_0-rmse:0.09008	validation_0-rmspe:inf	validation_1-rmse:0.08742	validation_1-rmspe:inf
# [199]	validation_0-rmse:0.08993	validation_0-rmspe:inf	validation_1-rmse:0.08734	validation_1-rmspe:inf
# [200]	validation_0-rmse:0.08988	validation_0-rmspe:inf	validation_1-rmse:0.08728	validation_1-rmspe:inf
# [201]	validation_0-rmse:0.08970	validation_0-rmspe:inf	validation_1-rmse:0.08710	validation_1-rmspe:inf
# [202]	validation_0-rmse:0.08957	validation_0-rmspe:inf	validation_1-rmse:0.08699	validation_1-rmspe:inf
# [203]	validation_0-rmse:0.08952	validation_0-rmspe:inf	validation_1-rmse:0.08692	validation_1-rmspe:inf
# [204]	validation_0-rmse:0.08939	validation_0-rmspe:inf	validation_1-rmse:0.08679	validation_1-rmspe:inf
# [205]	validation_0-rmse:0.08925	validation_0-rmspe:inf	validation_1-rmse:0.08673	validation_1-rmspe:inf
# [206]	validation_0-rmse:0.08913	validation_0-rmspe:inf	validation_1-rmse:0.08661	validation_1-rmspe:inf
# [207]	validation_0-rmse:0.08907	validation_0-rmspe:inf	validation_1-rmse:0.08657	validation_1-rmspe:inf
# [208]	validation_0-rmse:0.08903	validation_0-rmspe:inf	validation_1-rmse:0.08651	validation_1-rmspe:inf
# [209]	validation_0-rmse:0.08891	validation_0-rmspe:inf	validation_1-rmse:0.08638	validation_1-rmspe:inf
# [210]	validation_0-rmse:0.08885	validation_0-rmspe:inf	validation_1-rmse:0.08633	validation_1-rmspe:inf
# [211]	validation_0-rmse:0.08873	validation_0-rmspe:inf	validation_1-rmse:0.08628	validation_1-rmspe:inf
# [212]	validation_0-rmse:0.08868	validation_0-rmspe:inf	validation_1-rmse:0.08622	validation_1-rmspe:inf
# [213]	validation_0-rmse:0.08858	validation_0-rmspe:inf	validation_1-rmse:0.08611	validation_1-rmspe:inf
# [214]	validation_0-rmse:0.08847	validation_0-rmspe:inf	validation_1-rmse:0.08599	validation_1-rmspe:inf
# [215]	validation_0-rmse:0.08835	validation_0-rmspe:inf	validation_1-rmse:0.08589	validation_1-rmspe:inf
# [216]	validation_0-rmse:0.08823	validation_0-rmspe:inf	validation_1-rmse:0.08579	validation_1-rmspe:inf
# [217]	validation_0-rmse:0.08808	validation_0-rmspe:inf	validation_1-rmse:0.08568	validation_1-rmspe:inf
# [218]	validation_0-rmse:0.08799	validation_0-rmspe:inf	validation_1-rmse:0.08559	validation_1-rmspe:inf
# [219]	validation_0-rmse:0.08789	validation_0-rmspe:inf	validation_1-rmse:0.08550	validation_1-rmspe:inf
# [220]	validation_0-rmse:0.08785	validation_0-rmspe:inf	validation_1-rmse:0.08546	validation_1-rmspe:inf
# [221]	validation_0-rmse:0.08766	validation_0-rmspe:inf	validation_1-rmse:0.08518	validation_1-rmspe:inf
# [222]	validation_0-rmse:0.08762	validation_0-rmspe:inf	validation_1-rmse:0.08515	validation_1-rmspe:inf
# [223]	validation_0-rmse:0.08753	validation_0-rmspe:inf	validation_1-rmse:0.08504	validation_1-rmspe:inf
# [224]	validation_0-rmse:0.08744	validation_0-rmspe:inf	validation_1-rmse:0.08498	validation_1-rmspe:inf
# [225]	validation_0-rmse:0.08729	validation_0-rmspe:inf	validation_1-rmse:0.08478	validation_1-rmspe:inf
# [226]	validation_0-rmse:0.08724	validation_0-rmspe:inf	validation_1-rmse:0.08474	validation_1-rmspe:inf
# [227]	validation_0-rmse:0.08713	validation_0-rmspe:inf	validation_1-rmse:0.08468	validation_1-rmspe:inf
# [228]	validation_0-rmse:0.08707	validation_0-rmspe:inf	validation_1-rmse:0.08463	validation_1-rmspe:inf
# [229]	validation_0-rmse:0.08697	validation_0-rmspe:inf	validation_1-rmse:0.08456	validation_1-rmspe:inf
# [230]	validation_0-rmse:0.08688	validation_0-rmspe:inf	validation_1-rmse:0.08447	validation_1-rmspe:inf
# [231]	validation_0-rmse:0.08678	validation_0-rmspe:inf	validation_1-rmse:0.08433	validation_1-rmspe:inf
# [232]	validation_0-rmse:0.08672	validation_0-rmspe:inf	validation_1-rmse:0.08426	validation_1-rmspe:inf
# [233]	validation_0-rmse:0.08663	validation_0-rmspe:inf	validation_1-rmse:0.08414	validation_1-rmspe:inf
# [234]	validation_0-rmse:0.08656	validation_0-rmspe:inf	validation_1-rmse:0.08403	validation_1-rmspe:inf
# [235]	validation_0-rmse:0.08588	validation_0-rmspe:inf	validation_1-rmse:0.08324	validation_1-rmspe:inf
# [236]	validation_0-rmse:0.08581	validation_0-rmspe:inf	validation_1-rmse:0.08319	validation_1-rmspe:inf
# [237]	validation_0-rmse:0.08576	validation_0-rmspe:inf	validation_1-rmse:0.08316	validation_1-rmspe:inf
# [238]	validation_0-rmse:0.08567	validation_0-rmspe:inf	validation_1-rmse:0.08309	validation_1-rmspe:inf
# [239]	validation_0-rmse:0.08561	validation_0-rmspe:inf	validation_1-rmse:0.08302	validation_1-rmspe:inf
# [240]	validation_0-rmse:0.08554	validation_0-rmspe:inf	validation_1-rmse:0.08292	validation_1-rmspe:inf
# [241]	validation_0-rmse:0.08549	validation_0-rmspe:inf	validation_1-rmse:0.08289	validation_1-rmspe:inf
# [242]	validation_0-rmse:0.08540	validation_0-rmspe:inf	validation_1-rmse:0.08282	validation_1-rmspe:inf
# [243]	validation_0-rmse:0.08534	validation_0-rmspe:inf	validation_1-rmse:0.08274	validation_1-rmspe:inf
# [244]	validation_0-rmse:0.08525	validation_0-rmspe:inf	validation_1-rmse:0.08267	validation_1-rmspe:inf
# [245]	validation_0-rmse:0.08516	validation_0-rmspe:inf	validation_1-rmse:0.08260	validation_1-rmspe:inf
# [246]	validation_0-rmse:0.08509	validation_0-rmspe:inf	validation_1-rmse:0.08254	validation_1-rmspe:inf
# [247]	validation_0-rmse:0.08505	validation_0-rmspe:inf	validation_1-rmse:0.08250	validation_1-rmspe:inf
# [248]	validation_0-rmse:0.08494	validation_0-rmspe:inf	validation_1-rmse:0.08237	validation_1-rmspe:inf
# [249]	validation_0-rmse:0.08485	validation_0-rmspe:inf	validation_1-rmse:0.08231	validation_1-rmspe:inf
# [250]	validation_0-rmse:0.08475	validation_0-rmspe:inf	validation_1-rmse:0.08227	validation_1-rmspe:inf
# [251]	validation_0-rmse:0.08469	validation_0-rmspe:inf	validation_1-rmse:0.08219	validation_1-rmspe:inf
# [252]	validation_0-rmse:0.08461	validation_0-rmspe:inf	validation_1-rmse:0.08215	validation_1-rmspe:inf
# [253]	validation_0-rmse:0.08401	validation_0-rmspe:inf	validation_1-rmse:0.08145	validation_1-rmspe:inf
# [254]	validation_0-rmse:0.08398	validation_0-rmspe:inf	validation_1-rmse:0.08142	validation_1-rmspe:inf
# [255]	validation_0-rmse:0.08395	validation_0-rmspe:inf	validation_1-rmse:0.08140	validation_1-rmspe:inf
# [256]	validation_0-rmse:0.08389	validation_0-rmspe:inf	validation_1-rmse:0.08134	validation_1-rmspe:inf
# [257]	validation_0-rmse:0.08384	validation_0-rmspe:inf	validation_1-rmse:0.08126	validation_1-rmspe:inf
# [258]	validation_0-rmse:0.08379	validation_0-rmspe:inf	validation_1-rmse:0.08119	validation_1-rmspe:inf
# [259]	validation_0-rmse:0.08374	validation_0-rmspe:inf	validation_1-rmse:0.08116	validation_1-rmspe:inf
# [260]	validation_0-rmse:0.08369	validation_0-rmspe:inf	validation_1-rmse:0.08112	validation_1-rmspe:inf
# [261]	validation_0-rmse:0.08322	validation_0-rmspe:inf	validation_1-rmse:0.08054	validation_1-rmspe:inf
# [262]	validation_0-rmse:0.08317	validation_0-rmspe:inf	validation_1-rmse:0.08047	validation_1-rmspe:inf
# [263]	validation_0-rmse:0.08312	validation_0-rmspe:inf	validation_1-rmse:0.08039	validation_1-rmspe:inf
# [264]	validation_0-rmse:0.08304	validation_0-rmspe:inf	validation_1-rmse:0.08031	validation_1-rmspe:inf
# [265]	validation_0-rmse:0.08300	validation_0-rmspe:inf	validation_1-rmse:0.08023	validation_1-rmspe:inf
# [266]	validation_0-rmse:0.08292	validation_0-rmspe:inf	validation_1-rmse:0.08019	validation_1-rmspe:inf
# [267]	validation_0-rmse:0.08247	validation_0-rmspe:inf	validation_1-rmse:0.07964	validation_1-rmspe:inf
# [268]	validation_0-rmse:0.08233	validation_0-rmspe:inf	validation_1-rmse:0.07957	validation_1-rmspe:inf
# [269]	validation_0-rmse:0.08229	validation_0-rmspe:inf	validation_1-rmse:0.07951	validation_1-rmspe:inf
# [270]	validation_0-rmse:0.08224	validation_0-rmspe:inf	validation_1-rmse:0.07948	validation_1-rmspe:inf
# [271]	validation_0-rmse:0.08219	validation_0-rmspe:inf	validation_1-rmse:0.07945	validation_1-rmspe:inf
# [272]	validation_0-rmse:0.08211	validation_0-rmspe:inf	validation_1-rmse:0.07937	validation_1-rmspe:inf
# [273]	validation_0-rmse:0.08203	validation_0-rmspe:inf	validation_1-rmse:0.07930	validation_1-rmspe:inf
# [274]	validation_0-rmse:0.08201	validation_0-rmspe:inf	validation_1-rmse:0.07928	validation_1-rmspe:inf
# [275]	validation_0-rmse:0.08193	validation_0-rmspe:inf	validation_1-rmse:0.07919	validation_1-rmspe:inf
# [276]	validation_0-rmse:0.08189	validation_0-rmspe:inf	validation_1-rmse:0.07912	validation_1-rmspe:inf
# [277]	validation_0-rmse:0.08183	validation_0-rmspe:inf	validation_1-rmse:0.07907	validation_1-rmspe:inf
# [278]	validation_0-rmse:0.08174	validation_0-rmspe:inf	validation_1-rmse:0.07896	validation_1-rmspe:inf
# [279]	validation_0-rmse:0.08170	validation_0-rmspe:inf	validation_1-rmse:0.07894	validation_1-rmspe:inf
# [280]	validation_0-rmse:0.08167	validation_0-rmspe:inf	validation_1-rmse:0.07890	validation_1-rmspe:inf
# [281]	validation_0-rmse:0.08159	validation_0-rmspe:inf	validation_1-rmse:0.07881	validation_1-rmspe:inf
# [282]	validation_0-rmse:0.08155	validation_0-rmspe:inf	validation_1-rmse:0.07875	validation_1-rmspe:inf
# [283]	validation_0-rmse:0.08147	validation_0-rmspe:inf	validation_1-rmse:0.07869	validation_1-rmspe:inf
# [284]	validation_0-rmse:0.08143	validation_0-rmspe:inf	validation_1-rmse:0.07867	validation_1-rmspe:inf
# [285]	validation_0-rmse:0.08136	validation_0-rmspe:inf	validation_1-rmse:0.07858	validation_1-rmspe:inf
# [286]	validation_0-rmse:0.08132	validation_0-rmspe:inf	validation_1-rmse:0.07852	validation_1-rmspe:inf
# [287]	validation_0-rmse:0.08129	validation_0-rmspe:inf	validation_1-rmse:0.07850	validation_1-rmspe:inf
# [288]	validation_0-rmse:0.08126	validation_0-rmspe:inf	validation_1-rmse:0.07844	validation_1-rmspe:inf
# [289]	validation_0-rmse:0.08120	validation_0-rmspe:inf	validation_1-rmse:0.07839	validation_1-rmspe:inf
# [290]	validation_0-rmse:0.08118	validation_0-rmspe:inf	validation_1-rmse:0.07839	validation_1-rmspe:inf
# [291]	validation_0-rmse:0.08110	validation_0-rmspe:inf	validation_1-rmse:0.07831	validation_1-rmspe:inf
# [292]	validation_0-rmse:0.08103	validation_0-rmspe:inf	validation_1-rmse:0.07823	validation_1-rmspe:inf
# [293]	validation_0-rmse:0.08099	validation_0-rmspe:inf	validation_1-rmse:0.07821	validation_1-rmspe:inf
# [294]	validation_0-rmse:0.08092	validation_0-rmspe:inf	validation_1-rmse:0.07816	validation_1-rmspe:inf
# [295]	validation_0-rmse:0.08085	validation_0-rmspe:inf	validation_1-rmse:0.07809	validation_1-rmspe:inf
# [296]	validation_0-rmse:0.08078	validation_0-rmspe:inf	validation_1-rmse:0.07803	validation_1-rmspe:inf
# [297]	validation_0-rmse:0.08072	validation_0-rmspe:inf	validation_1-rmse:0.07799	validation_1-rmspe:inf
# [298]	validation_0-rmse:0.08069	validation_0-rmspe:inf	validation_1-rmse:0.07797	validation_1-rmspe:inf
# [299]	validation_0-rmse:0.08062	validation_0-rmspe:inf	validation_1-rmse:0.07789	validation_1-rmspe:inf
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.1, eval_metric=None,
#              feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#              max_leaves=None, min_child_weight=2, missing=nan,
#              monotone_constraints=None, n_estimators=1000, n_jobs=-1,
#              num_parallel_tree=None, predictor=None, ...)

# %%
print("Note that this is not in percentage, thus not to scale of graphs above")
xgb.plot_importance(xgboost_tree)
# Out:
# Note that this is not in percentage, thus not to scale of graphs above
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
def rmspe_exp(y, y_hat):
    return rmspe(np.expm1(y), np.expm1(y_hat))

rmpse_xg_scorer = make_scorer(rmspe_exp, greater_is_better = False) # Loss function

def score(model, X_train, y_train, y_test, y_hat):
    score = cross_val_score(model, X_train, y_train, scoring=rmpse_xg_scorer, cv=5)
    print('Mean', score.mean())
    print('Variance', score.var())
    print('RMSPE', rmspe(y_test, np.expm1(y_hat)))

y_hat = xgboost_tree.predict(X_test[X])
score(xgboost_tree, X_train[X], np.log1p(y_train), y_test, y_hat)
# Out:
# [13:51:28] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [13:51:47] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [13:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [13:52:26] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [13:52:44] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# Mean -inf
# Variance nan
# RMSPE inf
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:232: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
test = pd.read_csv("/content/gdrive/MyDrive/futureSales/assets/test.csv", parse_dates=[2], dtype=types)
features = build_features(test, store)

y_hat = np.expm1(xgboost_tree.predict(features[X]))

df = pd.DataFrame({"Id": range(1, len(test) + 1), 'Sales': y_hat})
df.loc[test['Open'] == 0, 'Sales'] = 1
df.to_csv('sales.csv', index=False)
# Out:
# <ipython-input-15-5dc1ec829914>:16: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   merged['Week'] = merged.Date.dt.week
# <ipython-input-15-5dc1ec829914>:28: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   (merged['Date'].dt.weekofyear - merged['Promo2SinceWeek'])

# %%
df.head
# Out:
# <bound method NDFrame.head of           Id     Sales
# 0          1  2.664946
# 1          2  2.664946
# 2          3  2.867891
# 3          4  2.867891
# 4          5  2.664946
# ...      ...       ...
# 33445  33446  2.664946
# 33446  33447  2.664946
# 33447  33448  2.867891
# 33448  33449  2.867891
# 33449  33450  2.664946
#
# [33450 rows x 2 columns]>
